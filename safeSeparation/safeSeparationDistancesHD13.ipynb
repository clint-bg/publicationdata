# %% [markdown]
# <a href="https://colab.research.google.com/github/clint-bg/publicationdata/blob/main/safeSeparation/safeSeparationDistancesHD13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Heat Flux and Safe Distances from Propellants and Fireworks
# ***
# ## Approach: Estimate the safe distance from test data
# This notebook summarizes over 750 heat flux experimental measurements by estimating the safe separation distance to prevent second degree burns. Some debris distances from confined events are also included. Clint Guymon
# ***
# ## Conclusions:
# - The safe separation distance is adequately captured by the existing US HD1.3 safe separation distances for unconfined scenarios.
# - Confined versus Unconfined scenarios are significantly different in the calculated safe separation distances due to the violence of the reaction

# %% [markdown]
# ***
# ## Necessary code and data import

# %%
#Import necessary packages
#%matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sea; #sea.set_palette(sea.color_palette("Set2")) #"Paired" "cubehelix"
from scipy.optimize import fsolve, minimize
from scipy.stats import t #import t distribution methods

# %% [markdown]
# ### Import data

# %% [markdown]
# The majority of the heat flux data is from "Scaling Studies of Thermal Radiation Flux from Burning Propellants" by J. Hay and R.W. Watson of Bureau of Mines as commissioned by the DDESB in 1992. Data from 14 other references of burning energetic material where the heat flux was measured is also summarized.

# %%
url = 'https://raw.githubusercontent.com/clint-bg/publicationdata/main/safeSeparation/heatfluxdataplus.csv' #url with raw data
df = pd.read_csv(url)

# %%
df.columns
# Out:
# Index(['Ref ID', 'Reference', 'Propellant Type', 'Test #', 'Mass (kg)',
#        'Fireball or Plume Distance (m)', 'Measurement Distance (m)',
#        'Burn Time (sec)', 'Peak Flux (cal/cm^2/s)', 'Av. Flux (cal/cm^2/s)',
#        'Hazard: Source', 'Event Type', 'Drum Diameter (cm)', 'Configuration',
#        'Notes'],
#       dtype='object')

# %%
#add new column for unique id = ref id + test id
df['Unique ID'] = df.agg('R{0[Ref ID]}T{0[Test #]}'.format, axis=1)

# %% [markdown]
# ## Data summary

# %%
summary = df.groupby('Ref ID')['Reference'].unique().to_frame()
summary['Propellant Types'] = df.groupby('Ref ID')['Propellant Type'].unique()
summary['# of Tests'] = df.groupby('Ref ID')['Unique ID'].nunique()
summary
# Out:
#                                                       Reference  \
# Ref ID
# 1             [Hay J. E. and Watson R. W. “Scaling Studies o...
# 10            [Joachim C E "M-1 Propellant Tests: Deflagrati...
# 11            [Farmer et al. “Combustion of Hazard Division ...
# 12            [Wilson W. Anderson J. and Meyden M. Titan IV ...
# 13            ["Internal Video Footage of Titan Rocket Motor...
# 2             [Harmanny A. “Thermal Radiation Flux of Firewo...
# 3             [Pape R. Waterman T. E. and Takata A. N. “Fire...
# 4             [Guymon C. G. “Heat Flux from the Top Ignition...
# 5             [Bon A. “Convective Combustion of Unconfined H...
# 6             [Bon A. “Convective Combustion of a Hazard Div...
# 7             [Blankenhagel P. Wehrstedt K.-D. Mishra K. B. ...
# 8             [Williams M. R. and Dunne J. L. “Heat Flux Mea...
# 9             [Allain L. “Combustion of Gun Propellant in Ig...
# China Lake 1  [Bon A. “M1 Propellant Testing Inside an ISO C...
# MSIAC 1       [Trinkler, "Thermal Effects in Relation to Amm...
# MSIAC 3       [Wyssen, "Abbrandversuche mit Treibladungspulv...
# MSIAC 4       [Wyssen, "Thermische Wirkgrössen bei Pulverabb...
# MSIAC 6       [Paquet F. Ng H. D. Paquet M. Cottin F. and Gr...
# MSIAC 7       [Lucotte, "Measurement and prediction of heat ...
#
#                                                Propellant Types  # of Tests
# Ref ID
# 1             [IMR5010, M1-8-SP, M1-8-MP, WC844, WC846, WCBl...          49
# 10                                                         [M1]           3
# 11                                                         [M1]           3
# 12                                          [Rocket Propellant]           1
# 13                                          [Rocket Propellant]           1
# 2                                                   [Fireworks]          16
# 3                                                   [M1, WC844]          46
# 4                                                       [WC814]           1
# 5                                                          [M1]           1
# 6                                                          [M1]           2
# 7                                      [di-tert-butyl peroxide]           3
# 8                                                         [MTV]          12
# 9                             [LB 7 T 72 (0,8) (Similar to M1)]           2
# China Lake 1                                               [M1]           2
# MSIAC 1                                               [Cordite]           8
# MSIAC 3                                 [GP11, 35mm propellant]          17
# MSIAC 4                                          [20 mm powder]           6
# MSIAC 6                                    [SB1, SB2, DB1, DB2]          16
# MSIAC 7                                      ["hunting powder"]           1

# %%
#References
for i,each in enumerate(set(df['Reference'])):
    print(i,":",each)
# Out:
# 0 : Wyssen, "Abbrandversuche mit Treibladungspulver in Mengen von 10 bis 1000 kg", Gruppe für Rüstungsdienste / Tecnische Abteilung 6, Feb 1982
# 1 : Lucotte, "Measurement and prediction of heat flux in gun propellant fires", Proceedings of the 20th DOD Safety Seminar, 1982
# 2 : Joachim C E "M-1 Propellant Tests: Deflagration in Partial Confinement" Technical Report SL-91-11 as referenced in TM 8668 Page 295+
# 3 : Trinkler, "Thermal Effects in Relation to Ammunition Storage", 1958
# 4 : Wyssen, "Thermische Wirkgrössen bei Pulverabbränden", Gruppe für Rüstungdienste / Technische Abteilung 6, Jan 1983
# 5 : Paquet F. Ng H. D. Paquet M. Cottin F. and Groulx D. “Modeling propellant fires radiant heat flux” Journal of Energetic Materials Vol. 37 No. 1 2019 pp. 110–124. https://doi.org/10.1080/07370652.2018.1542468
# 6 : Guymon C. G. “Heat Flux from the Top Ignition of a Single Barrel of WC814” Safety Management Services Inc. Unpublished Data 2020
# 7 : Blankenhagel P. Wehrstedt K.-D. Mishra K. B. and Steinbach J. “Thermal radiation assessment of fireballs using infrared camera” Journal of Loss Prevention in the Process Industries Vol. 54 2018 pp. 246–253. https://doi.org/10.1016/j.jlp.2018.04.008
# 8 : Bon A. “M1 Propellant Testing Inside an ISO Container” China Lake Ranges Test Operation Branch Unpublished Data 2020
# 9 : Wilson W. Anderson J. and Meyden M. Titan IV SRMU PQM-1 Overview 28th Joint Propulsion Conference and Exhibit 2012. https://doi.org/10.2514/6.1992-3819
# 10 : "Internal Video Footage of Titan Rocket Motor Ignition after Crane Failure” Safety Management Services Inc. 1990.
# 11 : Bon A. “Convective Combustion of Unconfined HD 1.3 Material in Fiber Barrels” China Lake Ranges Test Operation Branch(DB1110M) Unpublished Data 2020
# 12 : Bon A. “Convective Combustion of a Hazard Division 1.3 M1 Gun Propellant in Fiber Barrels Heat Flux Data” China Lake Ranges Test Operation Branch Unpublished Data 2020
# 13 : Allain L. “Combustion of Gun Propellant in Igloo Thermal Flux Measurements” US Army Corps of Engineers Vol. SNPE No. 153/91/-S/TS/NP 1991 in TM 8668 Page 300+
# 14 : Hay J. E. and Watson R. W. “Scaling Studies of Thermal Radiation Flux From Burning Propellants” Defense Technical Information Center Vol. 1992-08-01 No. ADA527525 1992 pp. 233–268
# 15 : Pape R. Waterman T. E. and Takata A. N. “Fire Hazards from Combustible Ammunition, Methodology Development (Phase I)” Defense Technical Information Center No. ADA093317 1980 pp. 0–154
# 16 : Farmer et al. “Combustion of Hazard Division 1.3 M1 Gun Propellant in a Reinforced Concrete Structure” Defense Technical Information Center Vol. NAWCWD TM8742 No. ADA622373 2015
# 17 : Harmanny A. “Thermal Radiation Flux of Fireworks” OECD-IGUS Report: Prins Maurits Laboratorium TNO 1992
# 18 : Williams M. R. and Dunne J. L. “Heat Flux Measurement from Bulk Magnesium/Teflon/Viton (MTV) Flare Composition Combustion” Propellants Explosives Pyrotechnics Vol. 38 No. 4 2013 pp. 563–568. https://doi.org/10.1002/prep.201200111

# %%
#propellant types
set(df['Propellant Type'])
# Out:
# {'"hunting powder"',
#  '20 mm powder',
#  '35mm propellant',
#  'Cordite',
#  'DB1',
#  'DB2',
#  'Fireworks',
#  'GP11',
#  'IMR5010',
#  'LB 7 T 72 (0,8) (Similar to M1)',
#  'M1',
#  'M1-8-MP',
#  'M1-8-SP',
#  'MTV',
#  'Rocket Propellant',
#  'SB1',
#  'SB2',
#  'WC814',
#  'WC844',
#  'WC846',
#  'WCBlank',
#  'di-tert-butyl peroxide'}

# %%
#number of tests for each propellant
df.groupby('Propellant Type')['Unique ID'].nunique(), df.groupby('Propellant Type')['Unique ID'].nunique().sum()
# Out:
# (Propellant Type
#  "hunting powder"                    1
#  20 mm powder                        6
#  35mm propellant                    15
#  Cordite                             8
#  DB1                                 4
#  DB2                                 2
#  Fireworks                          16
#  GP11                                2
#  IMR5010                            13
#  LB 7 T 72 (0,8) (Similar to M1)     2
#  M1                                 34
#  M1-8-MP                            12
#  M1-8-SP                            14
#  MTV                                12
#  Rocket Propellant                   2
#  SB1                                 5
#  SB2                                 5
#  WC814                               1
#  WC844                              27
#  WC846                               3
#  WCBlank                             3
#  di-tert-butyl peroxide              3
#  Name: Unique ID, dtype: int64, 190)

# %%
#total number of heat flux measurements
len(df)
# Out:
# 777

# %%
df.describe() #summary statistics for numerical data
# Out:
#            Mass (kg)  Fireball or Plume Distance (m)  \
# count     777.000000                       20.000000
# mean      879.750824                       36.585000
# std     11611.806873                       24.296681
# min         0.100000                        5.000000
# 25%        25.000000                       26.000000
# 50%        50.000000                       40.000000
# 75%       136.400000                       40.000000
# max    314158.000000                      126.000000
#
#        Measurement Distance (m)  Burn Time (sec)  Peak Flux (cal/cm^2/s)  \
# count                777.000000       741.000000              757.000000
# mean                   8.740412        27.760999                3.972361
# std                    8.526432        30.156340                8.207214
# min                    0.400000         0.400000                0.001505
# 25%                    3.000000         5.400000                0.173683
# 50%                    6.000000        17.000000                0.570000
# 75%                   12.000000        42.000000                2.919840
# max                  126.000000       215.000000               65.553588
#
#        Av. Flux (cal/cm^2/s)  Drum Diameter (cm)
# count             777.000000          154.000000
# mean                1.555819           59.376623
# std                 3.070879            3.829841
# min                 0.000000           36.000000
# 25%                 0.074000           60.000000
# 50%                 0.240000           60.000000
# 75%                 1.400000           60.000000
# max                24.737203           60.000000

# %%
df.head(3) #first 3 rows of the data frame
# Out:
#   Ref ID                                          Reference Propellant Type  \
# 0      1  Hay J. E. and Watson R. W. “Scaling Studies of...         IMR5010
# 1      1  Hay J. E. and Watson R. W. “Scaling Studies of...         IMR5010
# 2      1  Hay J. E. and Watson R. W. “Scaling Studies of...         IMR5010
#
#   Test #  Mass (kg)  Fireball or Plume Distance (m)  Measurement Distance (m)  \
# 0      1       45.4                             NaN                       8.0
# 1      1       45.4                             NaN                       6.4
# 2      1       45.4                             NaN                       5.0
#
#    Burn Time (sec)  Peak Flux (cal/cm^2/s)  Av. Flux (cal/cm^2/s)  \
# 0             35.0                   0.468                  0.127
# 1             35.0                   0.576                  0.161
# 2             35.0                   1.068                  0.289
#
#          Hazard: Source  Event Type  Drum Diameter (cm) Configuration   Notes  \
# 0  Heat Flux: Test Data  Unconfined                60.0           NaN  Barrel
# 1  Heat Flux: Test Data  Unconfined                60.0           NaN  Barrel
# 2  Heat Flux: Test Data  Unconfined                60.0           NaN  Barrel
#
#   Unique ID
# 0      R1T1
# 1      R1T1
# 2      R1T1

# %% [markdown]
# ## Plot of the Safe Heat Flux vs. Exposure Time

# %% [markdown]
# Safe heat flux is per 6055.09, 2012, V1.E9.3.1.2 to prevent second degree burns. with the included limit that after a duration of 20 seconds, the allowable heat flux remains constant with increasing exposure time.

# %%
#define a safe heat flux as a function of distance per second degree burns and a max exposure time of 20 seconds
#(per 6055.09, 2012, V1.E9.3.1.2 to prevent second degree burns)
qsafeat20 = 0.116 #qsafe at 20 second exposure
def safeHF(t):
    return (t/0.858)**(-1/1.46) if t<20 else qsafeat20

# %%
#add column for safe heat flux 
safeQ = df.groupby('Unique ID').apply(lambda x: np.percentile(
    [safeHF(x) for x in x['Burn Time (sec)']],75))
safeQ.name = 'Safe Heat Flux (cal/cm2/sec)'
#add to dataframe
df['Safe Heat Flux (cal/cm2/sec)'] = df['Unique ID'].apply(lambda x:safeQ.loc[x])

# %%
fig, ax = plt.subplots(1,1,figsize=(6,4))
x = np.arange(.1,200,0.05); y=[safeHF(x) for x in x]; 
ax.set_xscale('log');
plt.plot(x,y);
ax.fill_between(x,y,color="blue", alpha=0.1)
plt.text(0.2, 1, 'Safe');plt.text(3, 1, 'Unsafe');plt.text(40, 0.2, '0.116') #, bbox=dict(facecolor='red', alpha=0.5))
plt.text(.25,3,'$q_{safe}=(t/0.858)^{-1/1.46}$')
plt.xlabel('Exposure Time, sec');plt.ylabel('Heat Flux, cal/cm2/sec')
plt.show(block=False)

# %% [markdown]
# Here, burn time is equated to the exposure time. After 20 seconds the allowed heat flux is constant at 0.116 cal/cm2/s

# %% [markdown]
# ### Calculate a safe distance based on the point source model

# %% [markdown]
# Calculate a safe distance based on the average heat flux. The average heat flux is used instead of the peak heat flux as the peak heat flux is a short term event and is a small fraction of the total burn typically. The parameters of a Point Source Model are found according to the following where $r^2$ is the squared distance from the center of the fire:
# \begin{equation}
# q = \frac{\alpha}{r^2} \\
# \end{equation}

# %%
#completed for each test (unique id)
alphas = df.groupby('Unique ID').apply(lambda x: np.percentile(
    x['Av. Flux (cal/cm^2/s)']*x['Measurement Distance (m)']**2,75))
#alphas = [1 if each < 1 else each for each in alphas]
safeDistance = np.sqrt(alphas/safeQ)
safeDistance = pd.Series(safeDistance)
safeDistance.name = 'Safe Distance (m)'
safeDistance.index = safeQ.index

# %%
#add column for safe distance
df['Safe Distance (m)'] =  df['Unique ID'].apply(lambda x:safeDistance.loc[x])
#add column for burn rate
burnRate = df.groupby('Unique ID').apply(lambda x: np.percentile(x['Mass (kg)']/x['Burn Time (sec)'],50))
burnRate.name = 'Burn rate (kg/s)'
df['Burn Rate (kg/s)'] =  df['Unique ID'].apply(lambda x:burnRate.loc[x])

# %%
safeDistance = pd.DataFrame(safeDistance)
safeDistance['Propellant Type'] = df.groupby('Unique ID').apply(lambda x: x['Propellant Type'].iloc[0])
safeDistance['Mass (kg)'] = df.groupby('Unique ID').apply(lambda x: x['Mass (kg)'].iloc[0])
safeDistance['Safe Heat Flux (cal/cm2/sec)'] = df.groupby('Unique ID').apply(lambda x: x['Safe Heat Flux (cal/cm2/sec)'].iloc[0])
safeDistance['alphas'] = alphas

# %%
safeDistance[safeDistance['Propellant Type']=='M1-8-MP']
# Out:
#            Safe Distance (m) Propellant Type  Mass (kg)  \
# Unique ID
# R1T12               7.974583         M1-8-MP       47.6
# R1T16              11.077484         M1-8-MP       47.6
# R1T17               9.998706         M1-8-MP       47.6
# R1T24              14.137273         M1-8-MP       95.3
# R1T25              14.661709         M1-8-MP       95.3
# R1T3                8.683471         M1-8-MP       47.6
# R1T30              15.398794         M1-8-MP      190.5
# R1T33              10.339499         M1-8-MP       47.6
# R1T36              15.425773         M1-8-MP      142.9
# R1T39              18.711167         M1-8-MP      381.0
# R1T6                9.526153         M1-8-MP       47.6
# R1T9                8.639932         M1-8-MP       47.6
#
#            Safe Heat Flux (cal/cm2/sec)    alphas
# Unique ID
# R1T12                          0.199918  12.71360
# R1T16                          0.155406  19.07000
# R1T17                          0.164164  16.41216
# R1T24                          0.140897  28.16000
# R1T25                          0.140897  30.28800
# R1T3                           0.140897  10.62400
# R1T30                          0.116000  27.50625
# R1T33                          0.164164  17.55000
# R1T36                          0.117722  28.01250
# R1T39                          0.116000  40.61250
# R1T6                           0.116000  10.52672
# R1T9                           0.164164  12.25459

# %%
#example analysis result for Safe Distance given test results
df[df['Unique ID']=='R1T3']
# Out:
#    Ref ID                                          Reference Propellant Type  \
# 10      1  Hay J. E. and Watson R. W. “Scaling Studies of...         M1-8-MP
# 11      1  Hay J. E. and Watson R. W. “Scaling Studies of...         M1-8-MP
# 12      1  Hay J. E. and Watson R. W. “Scaling Studies of...         M1-8-MP
# 13      1  Hay J. E. and Watson R. W. “Scaling Studies of...         M1-8-MP
# 14      1  Hay J. E. and Watson R. W. “Scaling Studies of...         M1-8-MP
#
#    Test #  Mass (kg)  Fireball or Plume Distance (m)  \
# 10      3       47.6                             NaN
# 11      3       47.6                             NaN
# 12      3       47.6                             NaN
# 13      3       47.6                             NaN
# 14      3       47.6                             NaN
#
#     Measurement Distance (m)  Burn Time (sec)  Peak Flux (cal/cm^2/s)  \
# 10                       8.0             15.0                   0.420
# 11                       6.4             15.0                   0.504
# 12                       5.0             15.0                   1.032
# 13                       4.0             15.0                   1.000
# 14                       3.2             15.0                   1.600
#
#     Av. Flux (cal/cm^2/s)        Hazard: Source  Event Type  \
# 10                  0.166  Heat Flux: Test Data  Unconfined
# 11                  0.212  Heat Flux: Test Data  Unconfined
# 12                  0.464  Heat Flux: Test Data  Unconfined
# 13                  0.467  Heat Flux: Test Data  Unconfined
# 14                  0.733  Heat Flux: Test Data  Unconfined
#
#     Drum Diameter (cm) Configuration   Notes Unique ID  \
# 10                60.0           NaN  Barrel      R1T3
# 11                60.0           NaN  Barrel      R1T3
# 12                60.0           NaN  Barrel      R1T3
# 13                60.0           NaN  Barrel      R1T3
# 14                60.0           NaN  Barrel      R1T3
#
#     Safe Heat Flux (cal/cm2/sec)  Safe Distance (m)  Burn Rate (kg/s)
# 10                      0.140897           8.683471          3.173333
# 11                      0.140897           8.683471          3.173333
# 12                      0.140897           8.683471          3.173333
# 13                      0.140897           8.683471          3.173333
# 14                      0.140897           8.683471          3.173333

# %% [markdown]
# ## Add modeling results from COMSOL with Radiation in Participating Media
# COMSOL modeling was completed with a representative barrel of burning material at a given burn rate and temperature with radiative propagation from the hot gases.

# %%
url='https://raw.githubusercontent.com/clint-bg/publicationdata/main/safeSeparation/COMSOLModeling.csv'
dfm = pd.read_csv(url)
dft = pd.concat([df,dfm])

# %% [markdown]
# Note that there are many different ways that a safe distance could be estimated. The method used here is viewed by the authors as a conservative estimate. In previous plots, a modified version of the point source model with a 1/r dependence transitioning to a 1/r^2 dependence was used yielding slightly different results but with the same conclusion that the existing IBD line is effective in specifying a safe distance.

# %%
#Add additional lines
mlin = np.linspace(1,1000000,num=100000)
ibd = [max(22.9,np.exp(1.4715+0.2429*np.log(each)+0.00384*(np.log(each))**2)) if each<43544 else (np.exp(5.5938-0.5344*np.log(each)+0.04046*(np.log(each))**2) if each<453590 else 3.17*each**0.333) for each in mlin]
ibddf = pd.DataFrame({'masses (kg)':mlin,'ibd (m)':ibd})
natoibddf = pd.DataFrame({'NEQ (kg)':[1,	5,	10,	50,	100,	453,	500,	800,	1000,	5000,	10000,	43544,	500000,	1000000],'ibd (m)':[60,	60,	60,	60,	60,	60,	60,	60,	64,	109,	137,	225,	507,	640]})
DESR80df = pd.DataFrame({'NEQ (kg)':[1,10,50,100,150],'SafeD (m)':[3.22,7.97,15.0,19.7,22.9]})

# %%
#Plot a subset: unconfined burn data
fig, ax = plt.subplots(figsize=(12,8))
p = sea.scatterplot(data=dft[(dft['Event Type']=='Unconfined')],x='Mass (kg)',y='Safe Distance (m)', hue='Propellant Type', style='Propellant Type',s=100,ax=ax);
p = sea.lineplot(data=ibddf,x='masses (kg)',y='ibd (m)',ax=ax)
#p = sea.lineplot(data=DESR80,x='NEQ (kg)',y='SafeD (m)',ax=ax)
plt.plot(DESR80df['NEQ (kg)'],DESR80df['SafeD (m)'],color='#0270AF',linestyle=':')
p.set(xscale="log"); p.set(xlim=(1,1000000))
p.set(yscale="log"); p.set(ylim=(0.1,1000))
plt.legend(loc='lower right', fontsize=12)
plt.grid(linestyle = '--', linewidth = 0.5)
plt.grid(visible=True,which='minor',linestyle = '--', linewidth = 0.25)
ax.tick_params(axis='both', which='major', labelsize=12)
ax.set_xlabel('Mass (kg)', fontsize=14)
ax.set_ylabel('Heat Flux Separation Distance (m)', fontsize=14)
plt.savefig("SafeSepDistsU.png",dpi=600)
plt.show()

# %%
dft[(dft['Safe Distance (m)']>30) & (dft['Propellant Type']=='20 mm powder')]['Notes'].iloc[0]
# Out:
# 'Flux density determined using 2mm thick blackened aluminium plates. Max temperature was determined using irreversible temperature indicators; flux density then calculated using heat capacity of plates and tempreature differential. In addition, the temperature curve was recorded with the aid of an infrared radiometer. No duration values given: assume t=0.25Q^0.25'

# %%
dft[(dft['Safe Distance (m)']>30) & (dft['Propellant Type']=='DB1')]['Notes'].iloc[0]
# Out:
# 'Durations not provided; estimated using equation provided in paper 3.225Q^0.126; Ave heat flux is estimated from the peak heat flux/2'

# %% [markdown]
# ## Add in Confined Scenarios with Debris Distance (1/600) Estimates
# The 1/600 reference to the DESR 6055.09 criteria of one hazardous fragment per 600 square feet.

# %%
url='https://raw.githubusercontent.com/clint-bg/publicationdata/main/safeSeparation/ConfinedDebrisSafeDistances.csv'
dfd = pd.read_csv(url)
dfd['Safe Distance (m)'] = dfd['HFD (m)']
dfa = pd.concat([dft,dfd])

# %%
#Add in proposed lines and HD 1.2.2
onetwotwo = [max(30.5,28.127-2.364*np.log(each)+1.577*np.log(each)**2) for each in mlin]
newOneThree =  [min(3.216*each**0.3939,ibd[i]) for i,each in enumerate(mlin)]
onetwotwodf = pd.DataFrame({'masses (kg)':mlin,'ibd (m)':onetwotwo})
newOneThreedf = pd.DataFrame({'masses (kg)':mlin,'newibd (m)':newOneThree})
newConf = [onetwotwo[i] if each<1E4 else 6.4*each**0.333 for i,each in enumerate(mlin)]
newConfdf = pd.DataFrame({'masses (kg)':mlin,'ibd (m)':newConf})

# %%
fig, ax = plt.subplots(figsize=(12,8))
p = sea.scatterplot(data=dfa,x='Mass (kg)',y='Safe Distance (m)', style='Hazard: Source', hue='Event Type', s=75,ax=ax);
p = sea.lineplot(data=ibddf,x='masses (kg)',y='ibd (m)',linestyle=':',color='b',ax=ax)
p = sea.lineplot(data=onetwotwodf,x='masses (kg)',y='ibd (m)',linestyle='--',color='brown',ax=ax)
p = sea.lineplot(data=natoibddf,x='NEQ (kg)',y='ibd (m)',linestyle='-.',color='lightcoral',ax=ax)
p = sea.lineplot(data=newOneThreedf,x='masses (kg)',y='newibd (m)',color='b',alpha=0.3, linewidth = 6,ax=ax)
p = sea.lineplot(data=newConfdf,x='masses (kg)',y='ibd (m)',color='orangered',alpha=0.4, linewidth = 6,ax=ax)
#plt.plot(dfd['Mass (kg)'],dfd['HFD (m)'],color='g',marker='x',s=100,label='Hello')
p.set(xscale="log"); p.set(xlim=(1,1000000))
p.set(yscale="log"); p.set(ylim=(0.1,1000))
plt.legend(loc='best', fontsize=12)
plt.grid(linestyle = '--', linewidth = 0.5)
plt.grid(visible=True,which='minor',linestyle = '--', linewidth = 0.5)
ax.tick_params(axis='both', which='major', labelsize=12)
ax.set_xlabel('Mass (kg)', fontsize=14)
ax.set_ylabel('Explosives Safety Separation Distance (m)', fontsize=14)
plt.savefig("SafeSepDists.png",dpi=600)
plt.show()

# %%
sumdf = dfa.groupby('Reference')['Ref ID'].unique().to_frame()
sumdf['Propellant Types'] = dfa.groupby('Reference')['Propellant Type'].unique()
sumdf['# of Tests'] = dfa.groupby('Reference')['Unique ID'].nunique()
sumdf['Total # of Heat Flux Measurements']=dfa.groupby('Reference')['Av. Flux (cal/cm^2/s)'].count()
sumdf['Event Types']=dfa.groupby('Reference')['Event Type'].unique()
sumdf.to_csv('out.csv')
sumdf
# Out:
#                                                             Ref ID  \
# Reference
# "Internal Video Footage of Titan Rocket Motor I...            [13]
# Allain L. “Combustion of Gun Propellant in Iglo...             [9]
# Blankenhagel P. Wehrstedt K.-D. Mishra K. B. an...             [7]
# Bon A. “Convective Combustion of Unconfined HD ...             [5]
# Bon A. “Convective Combustion of a Hazard Divis...             [6]
# Bon A. “M1 Propellant Testing Inside an ISO Con...  [China Lake 1]
# Farmer A. Ford K. P. Covino J. Boggs T. L. and ...             [2]
# Farmer et al. “Combustion of Hazard Division 1....         [11, 1]
# Guymon C. G. “Heat Flux from the Top Ignition o...             [4]
# Guymon C. G. “Integrated Violence Model (IVM) o...             [7]
# Harmanny A. “Thermal Radiation Flux of Firework...             [2]
# Hay J. E. and Watson R. W. “Scaling Studies of ...             [1]
# Joachim C E "M-1 Propellant Tests: Deflagration...         [10, 3]
# Lucotte, "Measurement and prediction of heat fl...       [MSIAC 7]
# Pape R. Waterman T. E. and Takata A. N. “Fire H...             [3]
# Paquet F. Ng H. D. Paquet M. Cottin F. and Grou...       [MSIAC 6]
# Trinkler, "Thermal Effects in Relation to Ammun...       [MSIAC 1]
# Williams M. R. and Dunne J. L. “Heat Flux Measu...             [8]
# Wilson W. Anderson J. and Meyden M. Titan IV SR...         [12, 4]
# Wyssen, "Abbrandversuche mit Treibladungspulver...       [MSIAC 3]
# Wyssen, "Thermische Wirkgrössen bei Pulverabbrä...       [MSIAC 4]
#
#                                                                                      Propellant Types  \
# Reference
# "Internal Video Footage of Titan Rocket Motor I...                                [Rocket Propellant]
# Allain L. “Combustion of Gun Propellant in Iglo...                  [LB 7 T 72 (0,8) (Similar to M1)]
# Blankenhagel P. Wehrstedt K.-D. Mishra K. B. an...                           [di-tert-butyl peroxide]
# Bon A. “Convective Combustion of Unconfined HD ...                                               [M1]
# Bon A. “Convective Combustion of a Hazard Divis...                                               [M1]
# Bon A. “M1 Propellant Testing Inside an ISO Con...                                               [M1]
# Farmer A. Ford K. P. Covino J. Boggs T. L. and ...                                               [M1]
# Farmer et al. “Combustion of Hazard Division 1....                                               [M1]
# Guymon C. G. “Heat Flux from the Top Ignition o...                                            [WC814]
# Guymon C. G. “Integrated Violence Model (IVM) o...                                              [nan]
# Harmanny A. “Thermal Radiation Flux of Firework...                                        [Fireworks]
# Hay J. E. and Watson R. W. “Scaling Studies of ...  [IMR5010, M1-8-SP, M1-8-MP, WC844, WC846, WCBl...
# Joachim C E "M-1 Propellant Tests: Deflagration...                                               [M1]
# Lucotte, "Measurement and prediction of heat fl...                                 ["hunting powder"]
# Pape R. Waterman T. E. and Takata A. N. “Fire H...                                        [M1, WC844]
# Paquet F. Ng H. D. Paquet M. Cottin F. and Grou...                               [SB1, SB2, DB1, DB2]
# Trinkler, "Thermal Effects in Relation to Ammun...                                          [Cordite]
# Williams M. R. and Dunne J. L. “Heat Flux Measu...                                              [MTV]
# Wilson W. Anderson J. and Meyden M. Titan IV SR...                                [Rocket Propellant]
# Wyssen, "Abbrandversuche mit Treibladungspulver...                            [GP11, 35mm propellant]
# Wyssen, "Thermische Wirkgrössen bei Pulverabbrä...                                     [20 mm powder]
#
#                                                     # of Tests  \
# Reference
# "Internal Video Footage of Titan Rocket Motor I...           1
# Allain L. “Combustion of Gun Propellant in Iglo...           2
# Blankenhagel P. Wehrstedt K.-D. Mishra K. B. an...           3
# Bon A. “Convective Combustion of Unconfined HD ...           1
# Bon A. “Convective Combustion of a Hazard Divis...           2
# Bon A. “M1 Propellant Testing Inside an ISO Con...           2
# Farmer A. Ford K. P. Covino J. Boggs T. L. and ...           0
# Farmer et al. “Combustion of Hazard Division 1....           3
# Guymon C. G. “Heat Flux from the Top Ignition o...           1
# Guymon C. G. “Integrated Violence Model (IVM) o...           0
# Harmanny A. “Thermal Radiation Flux of Firework...          16
# Hay J. E. and Watson R. W. “Scaling Studies of ...          49
# Joachim C E "M-1 Propellant Tests: Deflagration...           3
# Lucotte, "Measurement and prediction of heat fl...           1
# Pape R. Waterman T. E. and Takata A. N. “Fire H...          46
# Paquet F. Ng H. D. Paquet M. Cottin F. and Grou...          16
# Trinkler, "Thermal Effects in Relation to Ammun...           8
# Williams M. R. and Dunne J. L. “Heat Flux Measu...          12
# Wilson W. Anderson J. and Meyden M. Titan IV SR...           1
# Wyssen, "Abbrandversuche mit Treibladungspulver...          17
# Wyssen, "Thermische Wirkgrössen bei Pulverabbrä...           6
#
#                                                     Total # of Heat Flux Measurements  \
# Reference
# "Internal Video Footage of Titan Rocket Motor I...                                  1
# Allain L. “Combustion of Gun Propellant in Iglo...                                 12
# Blankenhagel P. Wehrstedt K.-D. Mishra K. B. an...                                  9
# Bon A. “Convective Combustion of Unconfined HD ...                                  4
# Bon A. “Convective Combustion of a Hazard Divis...                                  7
# Bon A. “M1 Propellant Testing Inside an ISO Con...                                 16
# Farmer A. Ford K. P. Covino J. Boggs T. L. and ...                                  0
# Farmer et al. “Combustion of Hazard Division 1....                                  3
# Guymon C. G. “Heat Flux from the Top Ignition o...                                  4
# Guymon C. G. “Integrated Violence Model (IVM) o...                                  0
# Harmanny A. “Thermal Radiation Flux of Firework...                                 16
# Hay J. E. and Watson R. W. “Scaling Studies of ...                                206
# Joachim C E "M-1 Propellant Tests: Deflagration...                                  3
# Lucotte, "Measurement and prediction of heat fl...                                  1
# Pape R. Waterman T. E. and Takata A. N. “Fire H...                                 79
# Paquet F. Ng H. D. Paquet M. Cottin F. and Grou...                                 48
# Trinkler, "Thermal Effects in Relation to Ammun...                                 35
# Williams M. R. and Dunne J. L. “Heat Flux Measu...                                 36
# Wilson W. Anderson J. and Meyden M. Titan IV SR...                                  1
# Wyssen, "Abbrandversuche mit Treibladungspulver...                                176
# Wyssen, "Thermische Wirkgrössen bei Pulverabbrä...                                120
#
#                                                      Event Types
# Reference
# "Internal Video Footage of Titan Rocket Motor I...    [Confined]
# Allain L. “Combustion of Gun Propellant in Iglo...    [Confined]
# Blankenhagel P. Wehrstedt K.-D. Mishra K. B. an...    [Confined]
# Bon A. “Convective Combustion of Unconfined HD ...  [Unconfined]
# Bon A. “Convective Combustion of a Hazard Divis...  [Unconfined]
# Bon A. “M1 Propellant Testing Inside an ISO Con...    [Confined]
# Farmer A. Ford K. P. Covino J. Boggs T. L. and ...    [Confined]
# Farmer et al. “Combustion of Hazard Division 1....    [Confined]
# Guymon C. G. “Heat Flux from the Top Ignition o...  [Unconfined]
# Guymon C. G. “Integrated Violence Model (IVM) o...    [Confined]
# Harmanny A. “Thermal Radiation Flux of Firework...  [Unconfined]
# Hay J. E. and Watson R. W. “Scaling Studies of ...  [Unconfined]
# Joachim C E "M-1 Propellant Tests: Deflagration...    [Confined]
# Lucotte, "Measurement and prediction of heat fl...         [nan]
# Pape R. Waterman T. E. and Takata A. N. “Fire H...  [Unconfined]
# Paquet F. Ng H. D. Paquet M. Cottin F. and Grou...  [Unconfined]
# Trinkler, "Thermal Effects in Relation to Ammun...    [Confined]
# Williams M. R. and Dunne J. L. “Heat Flux Measu...    [Confined]
# Wilson W. Anderson J. and Meyden M. Titan IV SR...    [Confined]
# Wyssen, "Abbrandversuche mit Treibladungspulver...  [Unconfined]
# Wyssen, "Thermische Wirkgrössen bei Pulverabbrä...  [Unconfined]
